# %% [markdown]
# <a href="https://colab.research.google.com/github/unknxwNS/Ihopeitworks/blob/main/%D0%9B%D0%B5%D0%BA%D1%86%D1%96%D1%8F1_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Series - 1D

# %%
#!pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
mountain_height = pd.Series([2061, 2035.8, 2028.5, 2022.5, 2016.4])

mountain_height
# Out:
# 0    2061.0
# 1    2035.8
# 2    2028.5
# 3    2022.5
# 4    2016.4
# dtype: float64

# %%
mountain_height = pd.Series(
    data=[2061, 2035.8, 2028.5, 2022.5, 2016.4],
    index=["Goverla", "Brebenskyl", "Pip_Ivan", "Petros", "Gutin_Tomnatik"],
    name="Height, m",
    dtype=float,
)
mountain_height
# Out:
# Goverla           2061.0
# Brebenskyl        2035.8
# Pip_Ivan          2028.5
# Petros            2022.5
# Gutin_Tomnatik    2016.4
# Name: Height, m, dtype: float64

# %%
mountain_height[0]
# Out:
# /tmp/ipykernel_4383/1143873471.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mountain_height[0]
# np.float64(2061.0)

# %%
print(mountain_height['Goverla'])
# Out:
# 2061.0

# %%
mountain_height['Pip_Ivan']
# Out:
# np.float64(2028.5)

# %%
mountain_height[["Pip_Ivan", "Petros", "Goverla"]]
# Out:
# Pip_Ivan    2028.5
# Petros      2022.5
# Goverla     2061.0
# Name: Height, m, dtype: float64

# %%
mountain_height
# Out:
# Goverla           2061.0
# Brebenskyl        2035.8
# Pip_Ivan          2028.5
# Petros            2022.5
# Gutin_Tomnatik    2016.4
# Name: Height, m, dtype: float64

# %%
mountain_height[0:3]
# Out:
# Goverla       2061.0
# Brebenskyl    2035.8
# Pip_Ivan      2028.5
# Name: Height, m, dtype: float64

# %%
mountain_height["Goverla":"Petros"]
# Out:
# Goverla       2061.0
# Brebenskyl    2035.8
# Pip_Ivan      2028.5
# Petros        2022.5
# Name: Height, m, dtype: float64

# %%
mountain_height.Goverla
# Out:
# np.float64(2061.0)

# %%
mountain_height.Pip_Ivan
# Out:
# np.float64(2028.5)

# %%
mountain_height > 2030
# Out:
# Goverla            True
# Brebenskyl         True
# Pip_Ivan          False
# Petros            False
# Gutin_Tomnatik    False
# Name: Height, m, dtype: bool

# %%
mountain_height[mountain_height > 2030]
# Out:
# Goverla       2061.0
# Brebenskyl    2035.8
# Name: Height, m, dtype: float64

# %%
"Goverla" in mountain_height
# Out:
# True

# %%
"Goverls" in mountain_height
# Out:
# False

# %%
mountain_height.sort_values(inplace=True, ascending=True)

# %%
mountain_height
# Out:
# Gutin_Tomnatik    2016.4
# Petros            2022.5
# Pip_Ivan          2028.5
# Brebenskyl        2035.8
# Goverla           2061.0
# Name: Height, m, dtype: float64

# %%
mountains_height = pd.Series(
    {"Goverla": 2061, "Brebenskyl": 2035.8, "Pip_Ivan": 2028.5},
    index=["Goverla", "Brebenskyl", "Pip_Ivan", "Petros", "Gutin_Tomnatik"],
    name="Height, m",
    dtype=float,
)

mountains_height
# Out:
# Goverla           2061.0
# Brebenskyl        2035.8
# Pip_Ivan          2028.5
# Petros               NaN
# Gutin_Tomnatik       NaN
# Name: Height, m, dtype: float64

# %%
mountains_height.fillna(0, inplace=True)

mountains_height
# Out:
# Goverla           2061.0
# Brebenskyl        2035.8
# Pip_Ivan          2028.5
# Petros               0.0
# Gutin_Tomnatik       0.0
# Name: Height, m, dtype: float64

# %% [markdown]
# ## DataFrame - 2D

# %%
contacts = pd.DataFrame(
    {
        "name": [
            "Allen Raymond",
            "Chaim Lewis",
            "Kennedy Lane",
            "Wylie Pope",
            "Cyrus Jackson",
        ],
        "email": [
            "nulla.ante@vestibul.co.uk",
            "dui.in@egetlacus.ca",
            "mattis.Cras@nonenimMauris.net",
            "est@utquamvel.net",
            "nibh@semsempererat.com",
        ],
        "phone": [
            "(992) 914-3792",
            "(294) 840-6685",
            "(542) 451-7038",
            "(692) 802-2949",
            "(501) 472-5218",
        ],
        "favorite": [False, False, True, False, True],
    },
    index=[1, 2, 3, 4, 5],
)

contacts
# Out:
#             name                          email           phone  favorite
# 1  Allen Raymond      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 2    Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 3   Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 4     Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 5  Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True

# %%
# df[col] -> Series (вибір стовпця)
# df.loc[label] -> Series (вибір рядка за міткою)
# df.iloc[loc] -> Series (вибір рядка за індексом)
# df[0:3] -> DataFrame (зріз по рядкам)
# df[bool_vec] -> DataFrame (вибір рядків, які відповідають умові)

# %%
contacts['name']
# Out:
# 1    Allen Raymond
# 2      Chaim Lewis
# 3     Kennedy Lane
# 4       Wylie Pope
# 5    Cyrus Jackson
# Name: name, dtype: object

# %%
contacts.loc[1]
# Out:
# name                    Allen Raymond
# email       nulla.ante@vestibul.co.uk
# phone                  (992) 914-3792
# favorite                        False
# Name: 1, dtype: object

# %%
contacts[0:2]
# Out:
#             name                      email           phone  favorite
# 1  Allen Raymond  nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 2    Chaim Lewis        dui.in@egetlacus.ca  (294) 840-6685     False

# %%
contacts[contacts['favorite']]
# Out:
#             name                          email           phone  favorite
# 3   Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 5  Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True

# %% [markdown]
# ## Робота з CSV

# %%
# read_csv
# Params:
# filepath_or_buffer - шлях до файлу
# sep=',' - розділювач стовпців
# header=0 - номери рядків (індекси)
# names - імена стовпців
# nrows - кількість рядків для зчитування
# comment - коментар (не зчитувати)
# skip_blank_lines=True - пропуск порожніх рядків

# %%
housing = pd.read_csv('/content/sample_data/california_housing_test.csv')
housing
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
contacts = pd.DataFrame(
    {
        "name": [
            "Allen Raymond",
            "Chaim Lewis",
            "Kennedy Lane",
            "Wylie Pope",
            "Cyrus Jackson",
        ],
        "email": [
            "nulla.ante@vestibul.co.uk",
            "dui.in@egetlacus.ca",
            "mattis.Cras@nonenimMauris.net",
            "est@utquamvel.net",
            "nibh@semsempererat.com",
        ],
        "phone": [
            "(992) 914-3792",
            "(294) 840-6685",
            "(542) 451-7038",
            "(692) 802-2949",
            "(501) 472-5218",
        ],
        "favorite": [False, False, True, False, True],
    },
    index=[1, 2, 3, 4, 5],
)

contacts
# Out:
#             name                          email           phone  favorite
# 1  Allen Raymond      nulla.ante@vestibul.co.uk  (992) 914-3792     False
# 2    Chaim Lewis            dui.in@egetlacus.ca  (294) 840-6685     False
# 3   Kennedy Lane  mattis.Cras@nonenimMauris.net  (542) 451-7038      True
# 4     Wylie Pope              est@utquamvel.net  (692) 802-2949     False
# 5  Cyrus Jackson         nibh@semsempererat.com  (501) 472-5218      True

# %%
contacts.to_csv('/home/data.csv', index=False)

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.13/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.13/dist-packages (from openpyxl) (2.0.0)

# %%
contacts.to_excel('contacts.xlsx', sheet_name='Contacts')

# %%
import json

data = {
  "columns": ["name", "country"],
  "index": [1, 2, 3],
  "data": [
    ["Michael", "Canada"],
    ["John", "USA"],
    ["Liza", "Australia"]
  ]
}

with open('/content/data.json', 'w') as data_file:
  json.dump(data, data_file)

# %%
employees = pd.read_json('/content/data.json', orient="split")
employees
# Out:
#       name    country
# 1  Michael     Canada
# 2     John        USA
# 3     Liza  Australia

# %%
# records
[
  {
    "name": "Michael",
    "country": "Canada"
  },
  {
    "name": "John",
    "country": "USA"
  },
  {
    "name": "Liza",
    "country": "Australia"
  }
]
# Out:
# [{'name': 'Michael', 'country': 'Canada'},
#  {'name': 'John', 'country': 'USA'},
#  {'name': 'Liza', 'country': 'Australia'}]

# %%
# index
{
  "1": {
    "name": "Michael",
    "country": "Canada"
  },
  "2": {
    "name": "John",
    "country": "USA"
  },
  "3": {
    "name": "Liza",
    "country": "Australia"
  }
}
# Out:
# {'1': {'name': 'Michael', 'country': 'Canada'},
#  '2': {'name': 'John', 'country': 'USA'},
#  '3': {'name': 'Liza', 'country': 'Australia'}}

# %%
# columns
{
  "name": { "1": "Michael", "2": "John", "3": "Liza" },
  "country": { "1": "Canada", "2": "USA", "3": "Australia" }
}
# Out:
# {'name': {'1': 'Michael', '2': 'John', '3': 'Liza'},
#  'country': {'1': 'Canada', '2': 'USA', '3': 'Australia'}}

# %%
# values
[
  ["Michael", "Canada"],
  ["John", "USA"],
  ["Liza", "Australia"]
]
# Out:
# [['Michael', 'Canada'], ['John', 'USA'], ['Liza', 'Australia']]

# %%
data = {
  "name": { "1": "Michael", "2": "John", "3": "Liza" },
  "country": { "1": "Canada", "2": "USA", "3": "Australia" }
}
employees = pd.DataFrame(data)
employees.to_json('employees.json', orient='split')

# %% [markdown]
# ## HTML

# %% [markdown]
# ## Робота з даними

# %% [markdown]
# ### Додавання

# %%
data = pd.Series([1, 2, 3])
data[3] = 4
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
data = {
    "name": {"1": "Michael", "2": "John", "3": "Liza"},
    "country": {"1": "Canada", "2": "USA", "3": "Australia"}
}

employees = pd.DataFrame(data)
employees["age"] = [25, 32, 19]
print(employees)
# Out:
#       name    country  age
# 1  Michael     Canada   25
# 2     John        USA   32
# 3     Liza  Australia   19

# %%
data = {
    "name": {"1": "Michael", "2": "John", "3": "Liza"},
    "country": {"1": "Canada", "2": "USA", "3": "Australia"},
    "age": {"1": 25, "2": 32, "3": 19}
}

employees = pd.DataFrame(data)

new_employee = pd.Series(["Jhon", "Denmark", 23], ["name", "country", "age"])

employees = pd.concat([employees, new_employee.to_frame().T], ignore_index=True)
print(employees)
# Out:
#       name    country age
# 0  Michael     Canada  25
# 1     John        USA  32
# 2     Liza  Australia  19
# 3     Jhon    Denmark  23

# %% [markdown]
# ### Видалення

# %%
numbers = pd.Series([1, 2, 3, 4, 5])
numbers.drop([1,3], inplace=True)
print(numbers)
# Out:
# 0    1
# 2    3
# 4    5
# dtype: int64

# %%
data = {
    "name": {"1": "Michael", "2": "John", "3": "Liza"},
    "country": {"1": "Canada", "2": "USA", "3": "Australia"},
    "age": {"1": 25, "2": 32, "3": 19}
}

employees = pd.DataFrame(data)

employees = employees.drop(["2"])
print(employees)
# Out:
#       name    country  age
# 1  Michael     Canada   25
# 3     Liza  Australia   19

# %%
employees = employees.drop(["age"], axis=1)
employees
# Out:
#       name    country
# 1  Michael     Canada
# 3     Liza  Australia

# %%
data = {
    "name": {"1": "Michael", "2": "John", "3": "Liza"},
    "country": {"1": "Canada", "2": "USA", "3": "Australia"},
    "age": {"1": 25, "2": 32, "3": 19}
}

employees = pd.DataFrame(data)
employees['country']['1'] = None
employees
# Out:
# /tmp/ipykernel_4383/374020668.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   employees['country']['1'] = None
# /tmp/ipykernel_4383/374020668.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employees['country']['1'] = None
#       name    country  age
# 1  Michael       None   25
# 2     John        USA   32
# 3     Liza  Australia   19

# %%
data1 = {
    "name": {"1": "Michael", "2": "John"},
    "country": {"1": "Canada", "2": "USA"},
    "age": {"1": 25, "2": 32}
}

employees1 = pd.DataFrame(data1)

data2 = {
    "name": {"3": "Liza", "4": "Jhon"},
    "country": {"3": "Australia", "4": "Denmark"},
    "age": {"3": 19, "4": 23}
}

employees2 = pd.DataFrame(data2)

employees = pd.concat([employees1, employees2])

print(employees)
# Out:
#       name    country  age
# 1  Michael     Canada   25
# 2     John        USA   32
# 3     Liza  Australia   19
# 4     Jhon    Denmark   23

# %%
data1 = {
    "name": {"1": "Michael", "2": "John", "3": "Liza", "4": "Jhon"},
    "country": {"1": "Canada", "2": "USA", "3": "Australia", "4": "Denmark"}
}

employees1 = pd.DataFrame(data1)

data2 = {
    "age": {"1": 25, "2": 32, "3": 19, "4": 23}
}

employees2 = pd.DataFrame(data2)

employees = pd.concat([employees1, employees2], axis=1)

print(employees)
# Out:
#       name    country  age
# 1  Michael     Canada   25
# 2     John        USA   32
# 3     Liza  Australia   19
# 4     Jhon    Denmark   23

# %%
data = pd.DataFrame([[1, 2, 3], [4, np.nan, 6], [7, np.nan, np.nan]])

print(data)
# Out:
#    0    1    2
# 0  1  2.0  3.0
# 1  4  NaN  6.0
# 2  7  NaN  NaN

# %%
data.dropna()
# Out:
#    0    1    2
# 0  1  2.0  3.0

# %%
data = pd.DataFrame([[1, 2, 3], [4, np.nan, 6], [7, np.nan, np.nan]])

data = data.fillna({0: data[0].mean(), 1: data[1].mean(), 2: data[2].mean()})

print(data)
# Out:
#    0    1    2
# 0  1  2.0  3.0
# 1  4  2.0  6.0
# 2  7  2.0  4.5

# %%
data = {
    "name": ["Michael", "Steve", "Liza", "Jhon", "Liza", "Jhon"],
    "country": ["Canada", "USA", "Australia", "Denmark", "Australia", "Denmark"],
    "age": [25, 32, 19, 23, 19, 23]
}

employees = pd.DataFrame(data)
print(employees)

employees = employees.drop_duplicates()
print(employees)
# Out:
#       name    country  age
# 0  Michael     Canada   25
# 1    Steve        USA   32
# 2     Liza  Australia   19
# 3     Jhon    Denmark   23
# 4     Liza  Australia   19
# 5     Jhon    Denmark   23
#       name    country  age
# 0  Michael     Canada   25
# 1    Steve        USA   32
# 2     Liza  Australia   19
# 3     Jhon    Denmark   23

# %%
import pandas as pd
import matplotlib.pyplot as plt

s = pd.Series([10, 20, 15, 5], index=list("abcd"))
ax = s.plot(kind="bar", title="Sales")
# plt.show() у звичайному середовищі
